# %% [markdown]
# Task 13. Restoring staged  changes.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143939.png](<attachment:Снимок экрана 2025-01-19 143939.png>)

# %% [markdown]
# Task 12. Restoring previous versions.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143735.png](<attachment:Снимок экрана 2025-01-19 143735.png>)

# %% [markdown]
# Task 11. Creating versions' tags.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143557.png](<attachment:Снимок экрана 2025-01-19 143557.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-19 143540.png](<attachment:Снимок экрана 2025-01-19 143540.png>)

# %% [markdown]
# Task 10. Accessing previous versions.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143517.png](<attachment:Снимок экрана 2025-01-19 143517.png>)

# %% [markdown]
# Task 9.History of commits.

# %% [markdown]
# ![Снимок экрана 2025-01-19 125921.png](<attachment:Снимок экрана 2025-01-19 125921.png>)

# %% [markdown]
# Task 5 - 8. Indexation of commits.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143444.png](<attachment:Снимок экрана 2025-01-19 143444.png>)

# %% [markdown]
# Task 3 and 4. Checking the status and changing it.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143434.png](<attachment:Снимок экрана 2025-01-19 143434.png>)

# %% [markdown]
# Task 2. Committing changes.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143425.png](<attachment:Снимок экрана 2025-01-19 143425.png>)

# %% [markdown]
# Task 2. Initializing repository.

# %% [markdown]
# ![Снимок экрана 2025-01-19 143410.png](<attachment:Снимок экрана 2025-01-19 143410.png>)

# %% [markdown]
# Task 1. Setting user's name and email.

# %% [markdown]
# ![Снимок экрана 2025-01-19 123143.png](<attachment:Снимок экрана 2025-01-19 123143.png>)
